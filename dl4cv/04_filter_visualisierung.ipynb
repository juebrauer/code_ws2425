# %%
# !pip show keras-applications
# Out:
# WARNING: Package(s) not found: keras-applications

# %%
# !pip install keras-applications
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 385.7 kB/s eta 0:00:00 kB/s eta 0:00:01
# ...

# %%
from keras_applications import alexnet
from tensorflow.keras.optimizers import SGD

# AlexNet-Modell laden
model = alexnet.AlexNet(include_top=True, weights=None, input_shape=(227, 227, 3), classes=1000)

# Kompilieren
model.compile(optimizer=SGD(lr=0.01, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from keras_applications import alexnet
#       2 from tensorflow.keras.optimizers import SGD
#       4 # AlexNet-Modell laden
#
# ImportError: cannot import name 'alexnet' from 'keras_applications' (/home/juebrauer/miniconda3/envs/env_ss24/lib/python3.12/site-packages/keras_applications/__init__.py)

# %%
import keras_applications

# %%
# !pip install keras-alexnet
# Out:
# ERROR: Could not find a version that satisfies the requirement keras-alexnet (from versions: none)
# ERROR: No matching distribution found for keras-alexnet

# %%
import torch
alexnet = torch.hub.load('pytorch/vision:v0.10.0', 'alexnet', pretrained=True)
alexnet.eval()
# Out:
# Using cache found in /home/juebrauer/.cache/torch/hub/pytorch_vision_v0.10.0
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
# ...

# %%
alexnet
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
# ...

# %%
import matplotlib.pyplot as plt
for p in alexnet.parameters():
    print(p.shape)
    for filter_nr in range(64):
        f = p[filter_nr,:,:,:].detach().permute( [1,2,0] )
        min_filtervalue = float(min(f.flatten()))
        print(min_filtervalue)
        f += -min_filtervalue
        plt.imshow( f )
        plt.title(f"{filter_nr=}")
        plt.show()
    break
# Out:
# torch.Size([64, 3, 11, 11])
# 0.0
# -0.1918030083179474
# -0.3226690888404846
# -0.47198572754859924
# -0.33208832144737244
# -0.16713108122348785
# -0.2875954210758209
# -0.31329989433288574
# -0.25554320216178894
# -0.5348407626152039
# -0.4236029386520386
# -0.20390015840530396
# -0.3163806200027466
# -0.35026511549949646
# -0.3757532835006714
# -0.2082403302192688
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1952128].
# -0.6435428261756897
# -0.20675615966320038
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1319516].
# -0.49020498991012573
# -0.28480270504951477
# -0.4173547625541687
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.220202].
# -0.7062622904777527
# -0.2554963529109955
# -0.19346393644809723
# -0.6003304719924927
# ...

# %%
f.shape
# Out:
# torch.Size([11, 11, 3])
